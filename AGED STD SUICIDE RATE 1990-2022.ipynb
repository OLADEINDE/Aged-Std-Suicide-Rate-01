# %% [markdown]
# DATA ANALYSIS: AGED STD SUICIDE RATE 1990-2022

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\USER\Desktop\MetroHub_Projects_2024\Suicide Rates & Socioeconomic Factors (1990 - 22)\Age_std_suicide_rates_1990-2022.csv")
df
# Out:
#      RegionCode RegionName CountryCode CountryName  Year     Sex  \
# 0            EU     Europe         ALB     Albania  1992    Male
# 1            EU     Europe         ALB     Albania  1992  Female
# 2            EU     Europe         ALB     Albania  1993    Male
# 3            EU     Europe         ALB     Albania  1993  Female
# 4            EU     Europe         ALB     Albania  1994    Male
# ...         ...        ...         ...         ...   ...     ...
# 5923         AF     Africa         MYT     Mayotte  2015  Female
# 5924         AF     Africa         REU     R?union  2016    Male
# 5925         AF     Africa         REU     R?union  2016  Female
# 5926         AF     Africa         REU     R?union  2015    Male
# 5927         AF     Africa         REU     R?union  2015  Female
#
#       SuicideCount  CauseSpecificDeathPercentage  StdDeathRate  \
# 0               33                      0.331959      2.335802
# ...

# %%
df= df.drop_duplicates()
df
# Out:
#      RegionCode RegionName CountryCode CountryName  Year     Sex  \
# 0            EU     Europe         ALB     Albania  1992    Male
# 1            EU     Europe         ALB     Albania  1992  Female
# 2            EU     Europe         ALB     Albania  1993    Male
# 3            EU     Europe         ALB     Albania  1993  Female
# 4            EU     Europe         ALB     Albania  1994    Male
# ...         ...        ...         ...         ...   ...     ...
# 5923         AF     Africa         MYT     Mayotte  2015  Female
# 5924         AF     Africa         REU     R?union  2016    Male
# 5925         AF     Africa         REU     R?union  2016  Female
# 5926         AF     Africa         REU     R?union  2015    Male
# 5927         AF     Africa         REU     R?union  2015  Female
#
#       SuicideCount  CauseSpecificDeathPercentage  StdDeathRate  \
# 0               33                      0.331959      2.335802
# ...

# %%
df.shape
# Out:
# (5928, 17)

# %%
df.dropna()
# Out:
#      RegionCode RegionName CountryCode   CountryName  Year     Sex  \
# 0            EU     Europe         ALB       Albania  1992    Male
# 1            EU     Europe         ALB       Albania  1992  Female
# 2            EU     Europe         ALB       Albania  1993    Male
# 3            EU     Europe         ALB       Albania  1993  Female
# 4            EU     Europe         ALB       Albania  1994    Male
# ...         ...        ...         ...           ...   ...     ...
# 5366         AF     Africa         ZAF  South Africa  2016  Female
# 5368         AF     Africa         ZAF  South Africa  2017    Male
# 5369         AF     Africa         ZAF  South Africa  2017  Female
# 5370         AF     Africa         ZAF  South Africa  2018    Male
# 5371         AF     Africa         ZAF  South Africa  2018  Female
#
#       SuicideCount  CauseSpecificDeathPercentage  StdDeathRate  \
# 0               33                      0.331959      2.335802
# ...

# %%
df.head()
# Out:
#   RegionCode RegionName CountryCode CountryName  Year     Sex  SuicideCount  \
# 0         EU     Europe         ALB     Albania  1992    Male            33
# 1         EU     Europe         ALB     Albania  1992  Female            14
# 2         EU     Europe         ALB     Albania  1993    Male            46
# 3         EU     Europe         ALB     Albania  1993  Female            27
# 4         EU     Europe         ALB     Albania  1994    Male            37
#
#    CauseSpecificDeathPercentage  StdDeathRate  DeathRatePer100K  Population  \
# 0                      0.331959      2.335802          2.076386   3247039.0
# 1                      0.191860      0.866420          0.874563   3247039.0
# 2                      0.477724      3.330938          2.937233   3227287.0
# 3                      0.385164      1.755077          1.686025   3227287.0
# 4                      0.419406      2.678796          2.332619   3207536.0
#
# ...

# %% [markdown]
# # What was the average DeathRatePer100k in each RegionaName (Continents) per year ?

# %%
df['DeathRatePer100K'].mean()
# Out:
# 10.68800957452972

# %% [markdown]
# # What was the average DeathRatePer100K across all continents (RegionName) per year ?

# %%
df.groupby('Year')['DeathRatePer100K'].mean()
# Out:
# Year
# 1990    12.122140
# 1991    12.456348
# 1992    12.691845
# 1993    13.092438
# 1994    13.127761
# 1995    12.971534
# 1996    12.673692
# 1997    12.384870
# 1998    12.325487
# 1999    12.349663
# 2000    11.512529
# 2001    11.299607
# 2002    11.258436
# 2003    11.108574
# 2004    10.656086
# 2005    10.469971
# 2006    10.204323
# 2007    10.331796
# 2008    10.128627
# 2009    10.054286
# 2010     9.732921
# 2011     9.618181
# 2012     9.678313
# 2013     9.603686
# 2014     9.389315
# 2015     9.126767
# 2016     8.524834
# 2017     8.913204
# 2018     8.977835
# 2019     8.843312
# 2020     8.902533
# 2021     8.896424
# 2022    10.739026
# Name: DeathRatePer100K, dtype: float64

# %% [markdown]
# # What was the average DeathRatePer100K for Each distinct continents (RegionName) per year ?

# %%
df.pivot_table(index='Year', columns='RegionName',values='DeathRatePer100K').dropna()
# Out:
# RegionName     Africa      Asia  Central and South America     Europe  \
# Year
# 1990        14.190442  8.704203                   5.648321  17.961821
# 1991        13.233171  8.361601                   5.808314  18.119565
# 1992        13.896957  7.873526                   5.644576  18.182454
# 1993        12.974436  7.965218                   5.360607  19.075208
# 1994        11.956764  8.163260                   5.572240  19.410793
# 1995        13.511476  8.283924                   6.937450  19.102172
# 1996         7.132232  9.456301                   5.325757  18.983926
# 1997         5.603932  8.876754                   5.253675  18.864400
# 1998         7.104440  9.026625                   5.735024  18.378165
# 1999         7.959741  8.598522                   7.131888  18.174282
# 2000         4.210219  7.808467                   6.270201  18.165069
# 2001         6.220142  7.948010                   7.592878  17.856445
# ...

# %% [markdown]
# df.plot()

# %%
df.pivot_table(index='Year', columns=('Sex','RegionName'),values='DeathRatePer100K').dropna()
# Out:
# Sex            Female                                                \
# RegionName     Africa      Asia Central and South America    Europe
# Year
# 1990        10.758886  5.675550                  2.651646  8.825904
# 1991         8.291554  5.087055                  3.244590  8.695746
# 1992         8.775277  4.746405                  2.744413  8.729572
# 1993         8.487363  4.585322                  2.409082  8.675946
# 1994         4.087700  4.669342                  2.346149  8.273485
# 1995         5.891016  4.419149                  3.155691  8.357018
# 1996         3.348777  4.653647                  2.080518  8.013048
# 1997         1.848403  4.456852                  2.315400  7.964852
# 1998         3.742840  4.442815                  2.305481  7.729165
# 1999         4.873373  4.190406                  2.910249  7.735117
# 2000         1.819897  3.798332                  2.517146  7.738706
# 2001         2.862079  3.817032                  3.167489  7.433581
# ...

# %%
df.pivot_table(index='Year', columns='RegionName',aggfunc='sum',values='DeathRatePer100K').dropna()
# Out:
# RegionName     Africa        Asia  Central and South America       Europe  \
# Year
# 1990        28.380884  243.717688                 158.152984  1221.403805
# 1991        26.466341  234.124832                 139.399525  1268.369520
# 1992        27.793915  236.205774                 135.469822  1309.136687
# 1993        25.948873  223.026097                 139.375771  1373.414980
# 1994        23.913529  244.897805                 133.733750  1397.577085
# 1995        27.022953  265.085579                 194.248612  1375.356414
# 1996        28.528928  321.514227                 170.424220  1366.842704
# 1997        22.415726  337.316642                 168.117597  1320.508015
# 1998        28.417759  361.065013                 183.520770  1323.227901
# 1999        31.838965  361.137921                 228.220415  1344.896886
# 2000        25.261316  359.189481                 200.646438  1344.215077
# 2001        62.201416  349.712442                 273.343619  1321.376896
# ...

# %%
df.aggregate('Population').dropna()
# Out:
# 0       3247039.0
# 1       3247039.0
# 2       3227287.0
# 3       3227287.0
# 4       3207536.0
#           ...
# 5627      68398.0
# 5628      72572.0
# 5629      72572.0
# 5630      99258.0
# 5631      99258.0
# Name: Population, Length: 5632, dtype: float64

# %% [markdown]
# # What is the TOTAL suicide count in each in each continents (RegionName)

# %%
df2= df.groupby('RegionName')['SuicideCount'].mean()
df2
# Out:
# RegionName
# Africa                               63.125506
# Asia                               1291.118605
# Central and South America           673.899190
# Europe                             1605.904741
# North America and the Caribbean    1544.728199
# Oceania                             688.071429
# Name: SuicideCount, dtype: float64

# %%
df2.plot(kind='line',title='Suicide Count Across World Continents', ylabel='SuicideCount',xlabel='RegionName')
# Out:
# <Axes: title={'center': 'Suicide Count Across World Continents'}, xlabel='RegionName', ylabel='SuicideCount'>
